# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import date

Patients = pd.read_excel("HospitalDatabase .xlsx","Patients")
EDVisits = pd.read_excel("HospitalDatabase .xlsx","EDVisits")
AmbulatoryVisits = pd.read_excel("HospitalDatabase .xlsx","AmbulatoryVisits")
ReAdmissionRegistry = pd.read_excel("HospitalDatabase .xlsx","ReAdmissionRegistry")
Discharges = pd.read_excel("HospitalDatabase .xlsx","Discharges")
EDUnique= pd.read_excel("HospitalDatabase .xlsx","EDUnique")

Merged= pd.merge(Patients, Discharges, on="PatientID")
Merged1= pd.merge(Patients, ReAdmissionRegistry, on="PatientID",how= "left")

# %%
### 2. 101-200 patient name iloc

Patients.iloc[100:200, 1:3]
# Out:
#     FirstName   LastName
# 100     Calla    Wasiela
# 101     Gipsy   Frankton
# 102    Jethro     Wharin
# 103       Viv    Aylward
# 104     Swift  Dreschler
# ..        ...        ...
# 195  Cathlene    Kidwell
# 196      Noam   Laguerre
# 197      Arie    Bayless
# 198    Janaye    O'Mohun
# 199      Fonz      Group
#
# [100 rows x 2 columns]

# %%
#### 1. Make a pair plot on Readmission Registry table

sns.pairplot(ReAdmissionRegistry,palette='coolwarm')

# %%
#### 3. Create a figure object called fig using plt.figure()

import numpy as np
x = np.arange(0,100)
y = x*2

# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#####6. Create a jointplot on expected mortality & expected length of stay


sns.jointplot(x='ExpectedMortality',y='ExpectedLOS',data=ReAdmissionRegistry,kind='reg')

# %%
###8. Create a bar chart between expectedLOS & Primary diagnosis

sns.barplot(x='ExpectedLOS',y='PrimaryDiagnosis',data=df)
# Out:
# <AxesSubplot:xlabel='ExpectedLOS', ylabel='PrimaryDiagnosis'>

# %%
Patients['FullName'] = Patients['FirstName'] + ' ' + Patients["LastName"]
Patients["DateOfBirthYear"] = pd.to_datetime(Patients["DateOfBirth"]).dt.year
Patients[Patients["DateOfBirthYear"] == 1986]
# Out:
#      PatientID   FirstName    LastName             DateOfBirth  Gender  \
# 23          24    Gabriel       Joseph 1986-05-31 09:36:05.716    Male
# 24          25    Lincoln       Brenda 1986-07-24 17:36:00.791    Male
# 29          30         Ala     Halpert 1986-11-26 10:44:22.628  Female
# 72          74      Lolita       Darci 1986-01-08 02:34:04.596  Female
# 164        165       Fadel    Bernardt 1986-05-29 00:35:58.694    Male
# 238        239     Bentley      Kippax 1986-02-11 06:22:40.734    Male
# 367        368        Vale      Olanda 1986-04-15 00:49:58.690  Female
# 373        374       Britt     Dureden 1986-11-19 23:50:47.955  Female
# 386        387   Cristabel      Chatel 1986-07-10 16:27:30.640    Male
# 415        416  Constantia       Group 1986-03-26 06:37:22.525  Female
# 452        453      Morgan   Scrowston 1986-12-19 21:34:24.472  Female
# 561        562         Dom      Baglow 1986-07-26 14:43:49.240    Male
# ...

# %%
####10. Create a boxplot on ExpectedLOS by taking service into account

Discharges = pd.read_excel("HospitalDatabase .xlsx","Discharges")
sns.barplot(x='ExpectedLOS',y='Service',data=Discharges )
# Out:
# <AxesSubplot:xlabel='ExpectedLOS', ylabel='Service'>

# %%
#### 11. Create a pie chart by taking Service & ExpectedLOS_10_5_7_9


Discharges = pd.read_excel("HospitalDatabase .xlsx","Discharges")

Service= ["ICU", "Neurology", "General", "Medicine"] 
ExpectedLOS=[10,5,7,9]

outside = (0, 0, 0.5, 0) # Only explode on second slice
# Pie Chart
#startangle to start first data rotated 90 degree counterclcokwise from x-axis
plt.pie(ExpectedLOS, labels=Service, explode=outside, autopct="%.1f", shadow=True, startangle=90) 
plt.title("Pie Chart")
plt.show()

# %%
### 14. Find the number of null values in BloodPressureSystolic column

sum(pd.isnull(AmbulatoryVisits['BloodPressureSystolic']))
# Out:
# 124

# %% [markdown]
# ReAdmissionRegistry
#
# ReadmissionFlag = ReAdmissionRegistry.fillna({
#     'ReadmissionFlag' :0
# })
# ReadmissionFlag

# %%
### 17. Create a heat map to show the correlation between the column values of Edvisits

sns.heatmap(EDVisits.corr());

# %%
### 20.Create a visualization on the count of patients based on primary diagnosis and service


sns.countplot(y='PrimaryDiagnosis', hue='Service',data=ReAdmissionRegistry )
# Out:
# <AxesSubplot:xlabel='count', ylabel='PrimaryDiagnosis'>

# %%
sns.pairplot(EDVisits,hue='EDDisposition',palette='coolwarm')

# %%
corrEDvisits=EDVisits.corr()
sns.heatmap(corrEDvisits,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
####40. Plot a graph showing the count of patients for the reason visited the hospotal

sns.countplot(y='ReasonForVisit',data=EDUnique )
# Out:
# <AxesSubplot:xlabel='count', ylabel='ReasonForVisit'>

# %%
###37. Write a function to print all the upper case letter of a given sentence

string1 = 'tiny-python going places!!'
string1.upper()
# Out:
# 'TINY-PYTHON GOING PLACES!!'

# %%
###30. Which patient id has most entries in readmission registry.


print(ReAdmissionRegistry['PatientID'].value_counts())
# Out:
# 23     3
# 257    2
# 14     2
# 300    2
# 26     2
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 742    1
# Name: PatientID, Length: 704, dtype: int64

# %%
######74.  Get the list of ReasonForVisit.

Name_list = EDVisits["ReasonForVisit"].unique()

print (Name_list)
# Out:
# ['Stomach Ache' 'Migraine' 'Chest Pain' 'Bleeding' 'Car Accident'
#  'Pneumonia' 'Fever' 'Shortness of Breath' 'Gun Shot' 'Accident'
#  'Laceration' 'Intoxication' 'Cough']

# %%
####45. Calculate mortality by diagnosis

PrimaryDiagnosis_Exp = Discharges['PrimaryDiagnosis'].where(Discharges['DischargeDisposition'] =='Expired')
Mortality_count= PrimaryDiagnosis_Exp.count()
print( 'Mortality by diagnosis :',Mortality_count)
# Out:
# Mortality by diagnosis : 104

# %%
###41. Find the visit type with maximum 'No Show

VisitType_noShow= AmbulatoryVisits['VisitType'].where(AmbulatoryVisits['VisitStatus'] =='No Show').dropna().max()
print(VisitType_noShow)
# Out:
# Telemedicine

# %%
####38. Number of patients on 'Transfer' based on primary diagnosis

PrimaryDiagnosisTransfer = Discharges['PrimaryDiagnosis'].where(Discharges['DischargeDisposition'] =='Transfer').dropna()

rows_count = PrimaryDiagnosisTransfer.count()
print ('Patient count for transfer is:',rows_count )
# Out:
# Patient count for transfer is: 39

# %%
#### 36. Create a correlation matrix on EDVisits

corrEDvisits=EDVisits.corr()
sns.heatmap(corrEDvisits,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
###30. Which patient id has most entries in readmission registry

maxPatientID = ReAdmissionRegistry.max()['PatientID']
maxPatientID
# Out:
# 742

# %%
###25. Plot a graph by counting the no. of patients in each department

sns.countplot(y='VisitDepartmentID',data=AmbulatoryVisits )
# Out:
# <AxesSubplot:xlabel='count', ylabel='VisitDepartmentID'>

# %%
###27. Plot a graph to count the patients based on discharge disposition

sns.countplot(x='DischargeDisposition',data=ReAdmissionRegistry)
# Out:
# <AxesSubplot:xlabel='DischargeDisposition', ylabel='count'>

# %%
###50. Which departmentID has maximum number of visits scheduled

MaxScheduledDepartmentID= AmbulatoryVisits['VisitDepartmentID'].max()
print(" The maximum number of scheduled visit is for Departement ID : ", MaxScheduledDepartmentID)
# Out:
#  The maximum number of scheduled visit is for Departement ID :  12

# %%
###13. Create a subplot on x = np.arange(0, 10, 0.1) , y = np.sin(np.pi * x) + x with 2 rows & 2 columns with object oriented approach

import matplotlib.pyplot as plt
import numpy as np
 
x = np.arange(0, 10, 0.1)
y = np.sin(np.pi * x) + x
 
fig, ax = plt.subplots(1)

ax.plot(x, y)

ax.set_xlabel("x",fontsize=40)

ax.set_ylabel("y",fontsize=40)
# Out:
# Text(0, 0.5, 'y')

# %%
df = Merged.groupby(['Service','PrimaryDiagnosis']).size().unstack(fill_value=0)
df.head()
# Out:
# PrimaryDiagnosis  AMI  Afib  Broken Leg  Diabetes  Fever  Flu  Heart Failure  \
# Service
# Cardiology         40    10           3         0      0    2             39
# General Medicine    0     0           3        38     13   54              0
# Hospitalist         1     0           3        26      3   19              0
# ICU                 5     1           0         0      3    3             33
# Neurology           2     0           0         0      0    2              6
#
# PrimaryDiagnosis  Hip Fracture  Hypertension  Kidney Failure  \
# Service
# Cardiology                   0             0               1
# General Medicine             0            35              12
# Hospitalist                  0             6               6
# ICU                          0             4               1
# Neurology                    0             5               0
#
# PrimaryDiagnosis  Knee Replacement  Laceration  Migraine  Pain  Pneumonia  \
# Service
# ...

# %%
###21. Which demographic patients are prone to get stroke

Demographic = Merged['Race'].where(Merged['PrimaryDiagnosis']=='Stroke').dropna().max()
Demographic1 = Merged['Language'].where(Merged['PrimaryDiagnosis']=='Stroke').dropna().max()
###Demographic2 = Merged['Race'].where(Merged['PrimaryDiagnosis']=='Stroke').dropna().max()
print('Race having maximum stroke patients: ',Demographic )
print('Launguage having maximum stroke patients: ',Demographic1)
# Out:
# Race having maximum stroke patients:  White
# Launguage having maximum stroke patients:  Spanish

# %%
###52. Retrieve the row with minimum DBP using sorting technique

##Call dataframe
AmbulatoryVisits

##Sort and get minimum value by BPD
AmbulatoryVisits.sort_values(by=['BloodPressureDiastolic']).min()
# Out:
# VisitID                                            1
# PatientMRN                                         4
# ProviderID                                         1
# DateofVisit                      2019-01-01 00:00:00
# DateScheduled             2018-12-04 12:16:32.105000
# VisitDepartmentID                                  1
# VisitType                                  Follow Up
# BloodPressureSystolic                          120.0
# BloodPressureDiastolic                     51.695653
# Pulse                                      50.072068
# VisitStatus                                 Canceled
# dtype: object

# %%
####49. Retrieve the rows where SBP<140 and DBP<80

AmbulatoryVisits[(AmbulatoryVisits['BloodPressureSystolic'] < 140 ) & (AmbulatoryVisits['BloodPressureDiastolic'] < 80)]
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 5        809         894          31  2019-03-13 2019-02-28 10:28:01.091
# 16       707         859          36  2019-03-16 2019-02-26 17:42:39.779
# 18       503         887          12  2019-01-21 2019-01-07 06:04:17.575
# 19       710         862           1  2019-03-19 2019-03-03 11:39:03.145
# 23       711         863           1  2019-03-20 2019-03-10 07:34:56.766
# ..       ...         ...         ...         ...                     ...
# 909      177         815          32  2019-02-22 2019-02-04 06:53:41.987
# 929      786         871          34  2019-03-25 2019-02-26 09:48:42.832
# 932      394         623           6  2019-02-05 2019-01-10 05:43:34.544
# 941      399         638          11  2019-02-10 2019-02-02 20:49:56.868
# 943      403         650          15  2019-02-14 2019-02-11 00:47:42.216
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# ...

# %%
### 51. Display patient details where "ReasonForVisit" is either 'Migraine' or 'Pneumonia' and Acuity is 2 or more

Merged3= pd.merge(Patients, EDVisits, on="PatientID")
Merged3[(Merged3['ReasonForVisit'].isin(['Migraine','Pneumonia']))& (Merged3['Acuity']>=2)]
# Out:
#       PatientID  FirstName  LastName             DateOfBirth  Gender  \
# 4             3    Devlin    Michael 1976-04-15 02:52:09.762    Male
# 18            7    Skipton       Bar 1975-11-25 22:23:53.525    Male
# 20            8  Alexandra     Green 1967-06-16 16:37:21.694    Male
# 24           10     Granny       Man 1969-09-15 11:20:42.218    Male
# 27           12     Zonnya        Ab 1963-05-23 10:04:33.074    Male
# ...         ...        ...       ...                     ...     ...
# 1166        913       Alta   McGrath 1973-02-09 04:11:58.220  Female
# 1168        915   Jerrilyn     Dyson 1978-01-18 02:41:55.178  Female
# 1169        916     Kaylil   Baldack 1966-11-17 14:10:35.224  Female
# 1170        917     Velvet  Bushnell 1965-11-13 07:26:58.889  Female
# 1171        918       Kiri     Allom 1960-09-05 13:21:10.008  Female
#
#                         Race Language  EDVisitID               VisitDate  \
# ...

# %%
###62. Display the data for all 'White Female' patients above the age of 50.

df = pd.read_excel("HospitalDatabase .xlsx","Patients")

df["Age"] = (pd.to_datetime("today").year-pd.to_datetime(df["DateOfBirth"]).dt.year)

df[(df['Gender'] == 'Female' ) & (df['Race'] == "White") & (df['Age'] > 50)]
# Out:
#      PatientID  FirstName   LastName             DateOfBirth  Gender   Race  \
# 28          29        Ted      Scott 1967-12-09 05:01:37.892  Female  White
# 30          31      Harry       Ding 1960-10-08 01:42:51.212  Female  White
# 33          34        Ted        Hue 1960-11-28 18:05:11.459  Female  White
# 34          35       Fred        Tye 1966-04-14 06:01:07.169  Female  White
# 39          40  Christian        Pow 1971-12-07 11:47:43.885  Female  White
# ..         ...        ...        ...                     ...     ...    ...
# 865        866   Jermayne    Lowndes 1970-12-09 04:49:48.933  Female  White
# 866        867       Gail        Inc 1967-03-10 08:18:47.908  Female  White
# 867        868        Des  Heindrick 1969-08-15 11:05:30.165  Female  White
# 869        870      Hauck    Rubbens 1963-11-16 03:31:38.929  Female  White
# 873        874  Schroeder   McGarvey 1971-12-09 11:56:22.068  Female  White
#
#     Language  Age
# 28   Spanish   55
# ...

# %%
### 47. Using indexing , loc to retrieve the row with maximum BloodPressureSystolic

# get the row of max value
AmbulatoryVisits = pd.read_excel("HospitalDatabase .xlsx","AmbulatoryVisits")
AmbulatoryVisits.loc[AmbulatoryVisits['BloodPressureSystolic'].idxmax()]
# Out:
# VisitID                                          933
# PatientMRN                                       884
# ProviderID                                        27
# DateofVisit                      2019-02-14 00:00:00
# DateScheduled             2019-01-22 19:26:49.163000
# VisitDepartmentID                                 12
# VisitType                               Telemedicine
# BloodPressureSystolic                          190.0
# BloodPressureDiastolic                    143.989174
# Pulse                                      74.976879
# VisitStatus                                Completed
# Name: 236, dtype: object

# %%
###54. Mortality O.E.

CountofExpired = [(Discharges['DischargeDisposition'] == 'Expired').count()]

SumExpMort=[(Discharges['ExpectedMortality']).sum()]
values = {"CountofExpired":CountofExpired,"ExpectedMortality":SumExpMort}
d_frame = pd.DataFrame(values)
d_frame["MortalityOE"] = d_frame["CountofExpired"]/d_frame["ExpectedMortality"]

print(d_frame)
# Out:
#    CountofExpired  ExpectedMortality  MortalityOE
# 0             720         243.405269      2.95803
